# %%
import re
import json
import numpy as np
import pandas as pd
from string import punctuation
from sklearn.feature_extraction.text import TfidfVectorizer
# %matplotlib inline

# %%
corpus = []
with open('corpus.json', 'r') as f:
    corpus = json.load(f)

# %%
corpus[0]
# Out:
# 'Groundwater    Groundwater is the word used to describe water that saturates the ground, filling all the available spaces. By far the most abundant type of groundwater is meteoric water; this is the groundwater that circulates as part of the water cycle. Ordinary meteoric water is water that has soaked into the ground from the surface, from precipitation (rain and snow) and from lakes and streams. There it remains, sometimes for long periods, before emerging at the surface again. At first thought it seems incredible that there can be enough space in the “solid” ground underfoot to hold all this water.  The necessary space is there, however, in many forms. The commonest spaces are those among the particles—sand grains and tiny pebbles—of loose, unconsolidated sand and gravel. Beds of this material, out of sight beneath the soil, are common. They are found wherever fast rivers carrying loads of coarse sediment once flowed. For example, as the great ice sheets that covered North America during the last ice age steadily melted away, huge volumes of water flowed from them. The water was always laden with pebbles, gravel, and sand, known as glacial outwash, that was deposited as the flow slowed down.  The same thing happens to this day, though on a smaller scale, wherever a sediment-laden river or stream emerges from a mountain valley onto relatively flat land, dropping its load as the current slows: the water usually spreads out fanwise, depositing the sediment in the form of a smooth, fan-shaped slope. Sediments are also dropped where a river slows on entering a lake or the sea, the deposited sediments are on a lake floor or the seafloor at first, but will be located inland at some future date, when the sea level falls or the land rises, and such beds are sometimes thousands of meters thick.  In lowland country almost any spot on the ground may overlie what was once the bed of a river that has since become buried by soil; if they are now below the water’s upper surface (the water table), the gravels and sands of the former riverbed, and its sandbars, will be saturated with groundwater.  So much for unconsolidated sediments. Consolidated (or cemented) sediments, too, contain millions of minute water-holding pores. This is because the gaps among the original grains are often not totally plugged with cementing chemicals; also, parts of the original grains may become dissolved by percolating groundwater, either while consolidation is taking place or at any time afterwards. The result is that sandstone, for example, can be as porous as the loose sand from which it was formed.  Thus a proportion of the total volume of any sediment, loose or cemented, consists of empty space. Most crystalline rocks are much more solid; a common exception is basalt, a form of solidified volcanic lava, which is sometimes full of tiny bubbles that make it very porous.  The proportion of empty space in a rock is known as its porosity. But note that porosity is not the same as permeability, which measures the ease with which water can flow through a material; this depends on the sizes of the individual cavities and the crevices linking them.  Much of the water in a sample of water-saturated sediment or rock will drain from it if the sample is put in a suitable dry place. But some will remain, clinging to all solid surfaces. It is held there by the force of surface tension without which water would drain instantly from any wet surface, leaving it totally dry. The total volume of water in the saturated sample must therefore be thought of as consisting of water that can, and water that cannot, drain away.  The relative amount of these two kinds of water varies greatly from one kind of rock or sediment to another, even though their porosities may be the same. What happens depends on pore size. If the pores are large, the water in them will exist as drops too heavy for surface tension to hold, and it will drain away; but if the pores are small enough, the water i ...

# %%
def prepare_text(raw_text):
    punctuation_removed = raw_text.translate(str.maketrans(punctuation, ' ' * len(punctuation), '')).strip()
    lowered = punctuation_removed.lower()
    no_number = re.sub(r'\d+', '', lowered)
    return no_number

# %%
normal_corpus = list(map(prepare_text, corpus))

# %%
normal_corpus[0]
# Out:
# 'groundwater    groundwater is the word used to describe water that saturates the ground  filling all the available spaces  by far the most abundant type of groundwater is meteoric water  this is the groundwater that circulates as part of the water cycle  ordinary meteoric water is water that has soaked into the ground from the surface  from precipitation  rain and snow  and from lakes and streams  there it remains  sometimes for long periods  before emerging at the surface again  at first thought it seems incredible that there can be enough space in the “solid” ground underfoot to hold all this water   the necessary space is there  however  in many forms  the commonest spaces are those among the particles—sand grains and tiny pebbles—of loose  unconsolidated sand and gravel  beds of this material  out of sight beneath the soil  are common  they are found wherever fast rivers carrying loads of coarse sediment once flowed  for example  as the great ice sheets that covered north america during the last ice age steadily melted away  huge volumes of water flowed from them  the water was always laden with pebbles  gravel  and sand  known as glacial outwash  that was deposited as the flow slowed down   the same thing happens to this day  though on a smaller scale  wherever a sediment laden river or stream emerges from a mountain valley onto relatively flat land  dropping its load as the current slows  the water usually spreads out fanwise  depositing the sediment in the form of a smooth  fan shaped slope  sediments are also dropped where a river slows on entering a lake or the sea  the deposited sediments are on a lake floor or the seafloor at first  but will be located inland at some future date  when the sea level falls or the land rises  and such beds are sometimes thousands of meters thick   in lowland country almost any spot on the ground may overlie what was once the bed of a river that has since become buried by soil  if they are now below the water’s upper surface  the water table   the gravels and sands of the former riverbed  and its sandbars  will be saturated with groundwater   so much for unconsolidated sediments  consolidated  or cemented  sediments  too  contain millions of minute water holding pores  this is because the gaps among the original grains are often not totally plugged with cementing chemicals  also  parts of the original grains may become dissolved by percolating groundwater  either while consolidation is taking place or at any time afterwards  the result is that sandstone  for example  can be as porous as the loose sand from which it was formed   thus a proportion of the total volume of any sediment  loose or cemented  consists of empty space  most crystalline rocks are much more solid  a common exception is basalt  a form of solidified volcanic lava  which is sometimes full of tiny bubbles that make it very porous   the proportion of empty space in a rock is known as its porosity  but note that porosity is not the same as permeability  which measures the ease with which water can flow through a material  this depends on the sizes of the individual cavities and the crevices linking them   much of the water in a sample of water saturated sediment or rock will drain from it if the sample is put in a suitable dry place  but some will remain  clinging to all solid surfaces  it is held there by the force of surface tension without which water would drain instantly from any wet surface  leaving it totally dry  the total volume of water in the saturated sample must therefore be thought of as consisting of water that can  and water that cannot  drain away   the relative amount of these two kinds of water varies greatly from one kind of rock or sediment to another  even though their porosities may be the same  what happens depends on pore size  if the pores are large  the water in them will exist as drops too heavy for surface tension to hold  and it will drain away  but if the pores are small enough  the water i ...

# %%
from sklearn.feature_extraction import text
stop_words = text.ENGLISH_STOP_WORDS

# %%
vectorizer = TfidfVectorizer(stop_words=stop_words)
X = vectorizer.fit_transform(normal_corpus)

# %%
vectorizer.get_feature_names()
# Out:
# ['abandon',
#  'abandoned',
#  'abandoning',
#  'abbasid',
#  'abbreviated',
#  'abbreviation',
#  'abbé',
#  'abilities',
#  'ability',
#  'ablaze',
#  'able',
#  'aboard',
#  'abolished',
#  'abolishing',
#  'abominable',
#  'aboriginal',
#  'aborigines',
#  'abortive',
#  'abound',
#  'abounded',
#  'aboveground',
#  'abrabian',
#  'abrasion',
#  'abroad',
#  'abrogating',
#  'abrupt',
#  'abruptly',
#  'absence',
#  'absences',
#  'absent',
#  'absolute',
#  'absolutely',
#  'absorb',
#  'absorbed',
#  'absorbing',
#  'absorbs',
#  'absorption',
#  'abstract',
#  'abstraction',
#  'abstractions',
#  'absurd',
#  'abu',
#  'abundance',
#  'abundances',
#  'abundant',
#  'abundantly',
#  'abuse',
#  'abyss',
#  'acacia',
#  'academic',
#  'academically',
#  'accelerated',
#  'accelerates',
#  'accelerating',
#  'accentuated',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'accepting',
#  'access',
#  'accessible',
#  'accessory',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidents',
#  'acclimated',
#  'acclimatization',
#  'accommodate',
#  'accommodation',
#  'accompanied',
#  'accompanies',
#  'accompaniment',
#  'accompanying',
#  'accomplished',
#  'accomplishes',
#  'accomplishing',
#  'accord',
#  'accorded',
#  'according',
#  'accords',
#  'account',
#  'accountants',
#  'accounted',
#  'accounting',
#  'accounts',
#  'accumulate',
#  'accumulated',
#  'accumulates',
#  'accumulating',
#  'accumulation',
#  'accumulations',
#  'accumulators',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'accused',
#  'accustomed',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieving',
#  'acid',
#  'acidic',
#  'acidity',
#  'acids',
#  'acknowledges',
#  'acorns',
#  'acquire',
#  'acquired',
#  'acre',
#  'acreage',
#  'acres',
#  'acronym',
#  'act',
#  'acted',
#  'acting',
#  'action',
#  'actions',
#  'activated',
#  'active',
#  'actively',
#  'activities',
#  'activity',
#  'actor',
#  'actors',
#  'acts',
#  'actual',
#  'actually',
#  'ad',
#  'adapt',
#  'adaptation',
#  'adaptations',
#  'adapted',
#  'adapting',
#  'adaption',
#  'adaptive',
#  'adapts',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'additional',
#  'additionally',
#  'additions',
#  'addressing',
#  'adept',
#  'adequate',
#  'adjacent',
#  'adjectives',
#  'adjoining',
#  'adjust',
#  'adjusted',
#  'adjustment',
#  'adjustments',
#  'adjusts',
#  'administered',
#  'administration',
#  'administrative',
#  'administrators',
#  'admirable',
#  'admiration',
#  'admire',
#  'admired',
#  'admission',
#  'admit',
#  'admitted',
#  'adobe',
#  'adopt',
#  'adopted',
#  'adopting',
#  'adoption',
#  'adorned',
#  'adornment',
#  'adrenaline',
#  'adriatic',
#  'adrift',
#  'adult',
#  'adulterating',
#  'adulteration',
#  'adulthood',
#  'adults',
#  'advance',
#  'advanced',
#  'advancement',
#  'advancements',
#  'advances',
#  'advancing',
#  'advantage',
#  'advantaged',
#  'advantageous',
#  'advantages',
#  'advent',
#  'adventure',
#  'adventurer',
#  'adventures',
#  'adverse',
#  'advertise',
#  'advertised',
#  'advertisements',
#  'advertiser',
#  'advertisers',
#  'advertising',
#  'advice',
#  'advise',
#  'advised',
#  'advisers',
#  'advocated',
#  'adzes',
#  'aegean',
#  'aerated',
#  'aeration',
#  'aerial',
#  'aerodynamic',
#  'aeroponics',
#  'aesthetic',
#  'aesthetically',
#  'aestivation',
#  'afar',
#  'affairs',
#  'affect',
#  'affected',
#  'affecting',
#  'affects',
#  'affinities',
#  'affluent',
#  'afford',
#  'afforded',
#  'affords',
#  'afghanistan',
#  'afield',
#  'afraid',
#  'africa',
#  'african',
#  'africans',
#  'afterlife',
#  'agassiz',
#  'age',
#  'aged',
#  'agenbroad',
#  'agencies',
#  'agenda',
#  'agent',
#  'agents',
#  'ages',
#  'aggersund',
#  'aggregate',
#  'aggregated',
#  'aggregates',
#  'aggregations',
#  'aggression',
#  'aggressive',
#  'aggressiveness',
#  'agile',
#  'agnolo',
#  'ago',
#  'agora',
#  'agree',
#  'agreed',
#  'agreement',
#  'agreements',
#  'agrees',
#  'agricultural',
#  'agriculturalists',
#  'agriculturally',
#  'agriculture',
#  'ahead',
#  'aid',
#  'aided',
#  'aids',
#  'aimed',
#  'aims',
#  'ain',
#  'air',
#  'airborne',
#  'airflow',
#  'airplanes',
#  'airs',
#  'airway',
#  'airways',
#  'akkad',
#  'akkadians',
#  'al',
#  'alarm',
#  'alarming',
#  'alas',
#  'alaska',
#  'alaskan',
#  'albedo',
#  'albeit',
#  'alberta',
#  'alder',
#  'aleksandr',
#  'alembert',
#  'alert',
#  'alertness',
#  'alexander',
#  'alexandria',
#  'alfalfa',
#  'alfred',
#  'alga',
#  'algae',
#  'alien',
#  'aliens',
#  'alif',
#  'alike',
#  'alimentary',
#  'alio',
#  'alive',
#  'alkali',
#  'allegedly',
#  'allende',
#  'allergies',
#  'alliances',
#  'allies',
#  'allopatric',
#  'allopatry',
#  'allow',
#  'allowed',
#  'allowing',
#  'allows',
#  'alloy',
#  'alloyed',
#  'allusion',
#  'alluvial',
#  'ally',
#  'alongside',
#  'aloud',
#  'alphabet',
#  'alpine',
#  'alps',
#  'alter',
#  'alteration',
#  'alterations',
#  'altered',
#  'altering',
#  'alternate',
#  'alternated',
#  'alternative',
#  'alternatively',
#  'alternatives',
#  'alterniflora',
#  'altitude',
#  'altitudes',
#  'altogether',
#  'aluminum',
#  'alvarez',
#  'amasis',
#  'amassed',
#  'amateur',
#  'amati',
#  'amazing',
#  'amazon',
#  'ambient',
#  'ambitions',
#  'ambitious',
#  'ambitiously',
#  'amborella',
#  'ambulocetus',
#  'ambushing',
#  'ameliorate',
#  'amended',
#  'amenities',
#  'america',
#  'american',
#  'americanisms',
#  'americans',
#  'americas',
#  'amethyst',
#  'amino',
#  'ammonia',
#  'ammonites',
#  'ammonoid',
#  'ammonoids',
#  'amnesia',
#  'amniotic',
#  'amounted',
#  'amounting',
#  'amounts',
#  'amphibian',
#  'amphibians',
#  'amphorae',
#  'ample',
#  'amplification',
#  'amply',
#  'amsterdam',
#  'amuse',
#  'amusement',
#  'anaerobic',
#  'analogies',
#  'analogous',
#  'analogy',
#  'analyses',
#  'analysis',
#  'analyst',
#  'analyze',
#  'analyzed',
#  'analyzing',
#  'anarchy',
#  'anatolia',
#  'anatomical',
#  'anatomy',
#  'anaximander',
#  'anaximenes',
#  'ancestor',
#  'ancestors',
#  'ancestral',
#  'ancestry',
#  'anchor',
#  'anchovies',
#  'ancient',
#  'andean',
#  'andes',
#  'andree',
#  'andrew',
#  'anecdotal',
#  'anemone',
#  'anemones',
#  'angiosperm',
#  'angiosperms',
#  'angkor',
#  'angle',
#  'angles',
#  'angling',
#  'angular',
#  'angularity',
#  'animal',
#  'animals',
#  'animated',
#  'ankle',
#  'ann',
#  'annihilated',
#  'announced',
#  'annual',
#  'annually',
#  'annuals',
#  'annum',
#  'anomalies',
#  'anomalocaris',
#  'anomaly',
#  'anonymous',
#  'answer',
#  'answered',
#  'answering',
#  'answers',
#  'ant',
#  'antagonists',
#  'antarctic',
#  'antarctica',
#  'antecedents',
#  'antelope',
#  'antelopes',
#  'anthocyanin',
#  'anthropologically',
#  'anthropologist',
#  'anthropologists',
#  'anthropology',
#  'anthropomorphism',
#  'anticipate',
#  'anticipated',
#  'anticipation',
#  'antifreeze',
#  'antioch',
#  'antiquity',
#  'antler',
#  'antlers',
#  'antonio',
#  'ants',
#  'antwerp',
#  'anu',
#  'anxieties',
#  'anxious',
#  'apart',
#  'apartment',
#  'apartments',
#  'apeiron',
#  'apex',
#  'apiece',
#  'appalachian',
#  'appalachians',
#  'apparatus',
#  'apparent',
#  'apparently',
#  'appeal',
#  'appealing',
#  'appeals',
#  'appear',
#  'appearance',
#  'appearances',
#  'appeared',
#  'appearing',
#  'appears',
#  'appendages',
#  'appetite',
#  'applause',
#  'applicable',
#  'application',
#  'applications',
#  'applied',
#  'applies',
#  'apply',
#  'applying',
#  'appointed',
#  'appointing',
#  'apportioning',
#  'appraisal',
#  'appreciably',
#  'appreciate',
#  'appreciated',
#  'apprehension',
#  'apprenticed',
#  'approach',
#  'approached',
#  'approaches',
#  'approaching',
#  'appropriate',
#  'appropriately',
#  'approved',
#  'approximate',
#  'approximately',
#  'approximating',
#  'april',
#  'aquatic',
#  'aquicludes',
#  'aquifer',
#  'aquifers',
#  'arab',
#  'arabia',
#  'arabian',
#  'arabic',
#  'arable',
#  'aragonite',
#  'arbitrary',
#  'arboreal',
#  'arcades',
#  'arch',
#  'archaeocyte',
#  'archaeological',
#  'archaeologist',
#  'archaeologists',
#  'archaeology',
#  'archaic',
#  'archean',
#  'archeologists',
#  'archipelago',
#  'architect',
#  'architects',
#  'architectural',
#  'architecturally',
#  'architecture',
#  'archives',
#  'arctic',
#  'arduous',
#  'area',
#  'areas',
#  'aren',
#  'argon',
#  'argue',
#  'argued',
#  'argues',
#  'argument',
#  'arguments',
#  'arid',
#  'aridity',
#  'arise',
#  'arisen',
#  'arises',
#  'arising',
#  'aristocracy',
#  'aristocratic',
#  'aristocrats',
#  'aristotle',
#  'arizona',
#  'arkansas',
#  'arm',
#  'armat',
#  'armed',
#  'armenia',
#  'armful',
#  'armies',
#  'arms',
#  'army',
#  'arnolfini',
#  'arose',
#  'arouse',
#  'arrange',
#  'arranged',
#  'arrangement',
#  'arranging',
#  'array',
#  'arrival',
#  'arrive',
#  'arrived',
#  'arrow',
#  'arsenale',
#  'arsenic',
#  'arson',
#  'art',
#  'artery',
#  'arthropod',
#  'arthropods',
#  'arthur',
#  'articulations',
#  'artifact',
#  'artifacts',
#  'artificial',
#  'artificially',
#  'artisan',
#  'artisans',
#  'artist',
#  'artistic',
#  'artistry',
#  'artists',
#  'arts',
#  'artworks',
#  'ash',
#  'ashes',
#  'ashore',
#  'ashurbanipal',
#  'asia',
#  'asian',
#  'aside',
#  'asked',
#  'asleep',
#  'aspect',
#  'aspects',
#  'asphalt',
#  'aspirations',
#  'assemblage',
#  'assemble',
#  'assembled',
#  'assemblies',
#  'assembly',
#  'assert',
#  'asserted',
#  'assertion',
#  'assess',
#  'assessing',
#  'assessment',
#  'assets',
#  'assigned',
#  'assist',
#  'assistance',
#  'assistant',
#  'assistants',
#  'assisted',
#  'assists',
#  'associate',
#  'associated',
#  'associates',
#  'associating',
#  'association',
#  'associational',
#  'associations',
#  'assorted',
#  'assortment',
#  'assume',
#  'assumed',
#  'assumes',
#  'assuming',
#  'assumption',
#  'assumptions',
#  'assured',
#  'assyria',
#  'assyrians',
#  'astarte',
#  'asteroid',
#  'asteroids',
#  'astonishing',
#  'astoundingly',
#  'astrolabe',
#  'astronomer',
#  'astronomers',
#  'astronomical',
#  'astronomy',
#  'asymmetrical',
#  'ataturk',
#  'ate',
#  'athenian',
#  'athenians',
#  'athens',
#  'athletes',
#  'atkin',
#  'atlantic',
#  'atlas',
#  'atmosphere',
#  'atmospheres',
#  'atmospheric',
#  'ato',
#  'atoll',
#  'atolls',
#  'atom',
#  'atomic',
#  'atoms',
#  'attached',
#  'attaching',
#  'attachment',
#  'attack',
#  'attacking',
#  'attain',
#  'attained',
#  'attains',
#  'attempt',
#  'attempted',
#  'attempting',
#  'attempts',
#  'attendants',
#  'attended',
#  'attending',
#  'attention',
#  'attest',
#  'attests',
#  'attic',
#  'attica',
#  'attitude',
#  'attitudes',
#  'attract',
#  'attracted',
#  'attracting',
#  'attraction',
#  'attractions',
#  'attractive',
#  'attracts',
#  'attribute',
#  'attributed',
#  'attributes',
#  'audience',
#  'audiences',
#  'audio',
#  'auditory',
#  'augmented',
#  'august',
#  'auguste',
#  'aural',
#  'australia',
#  'australian',
#  'australians',
#  'austrian',
#  'austronesian',
#  'authenticity',
#  'author',
#  'authored',
#  'authoritative',
#  'authorities',
#  'authority',
#  'authorizing',
#  'authors',
#  'autobiographical',
#  'automate',
#  'automatic',
#  'automatically',
#  'automobile',
#  'automobiles',
#  'autonomous',
#  'autonomy',
#  'autumn',
#  'aux',
#  'auxiliary',
#  'availability',
#  'available',
#  'avalanches',
#  'avenues',
#  'average',
#  'averages',
#  'avoid',
#  'avoidance',
#  'avoided',
#  'avoiding',
#  'await',
#  'awaited',
#  'awaiting',
#  'aware',
#  'awareness',
#  'away',
#  'awesome',
#  'awkward',
#  'awkwardness',
#  'axes',
#  'axis',
#  'azoic',
#  'ba',
#  'babies',
#  'baby',
#  'babylon',
#  'babylonian',
#  'babylonians',
#  'bach',
#  'backbone',
#  'backbones',
#  'backdrops',
#  'backed',
#  'background',
#  'backtracking',
#  'backward',
#  'backwater',
#  'bacteria',
#  'bacterial',
#  'bacterium',
#  'bad',
#  'baffin',
#  'baghdad',
#  'bake',
#  'baked',
#  'bakes',
#  'baking',
#  'balance',
#  'balanced',
#  'balances',
#  'balconies',
#  'baleen',
#  'ball',
#  'ballads',
#  'balloon',
#  'balsa',
#  'baltic',
#  'banana',
#  'bananas',
#  'band',
#  'bands',
#  'bangkok',
#  'bank',
#  'bankers',
#  'banking',
#  'banks',
#  'banner',
#  'bantu',
#  'bar',
#  'barbara',
#  'bare',
#  'barely',
#  'bargains',
#  'bark',
#  'barked',
#  'barks',
#  'barley',
#  'baroque',
#  'barrel',
#  'barrels',
#  'barren',
#  'barrens',
#  'barrier',
#  'barriers',
#  'bars',
#  'bartering',
#  'basalt',
#  'basaltic',
#  'base',
#  'based',
#  'bases',
#  'basic',
#  'basically',
#  'basilica',
#  'basilosaurus',
#  'basin',
#  'basins',
#  'basis',
#  'baskets',
#  'basking',
#  'bat',
#  'batch',
#  'batches',
#  'bath',
#  'bathed',
#  'bathhouse',
#  'batlike',
#  'bats',
#  'battery',
#  'battista',
#  'battle',
#  'battles',
#  'battleship',
#  'bay',
#  'bays',
#  'bc',
#  'beach',
#  'beaches',
#  'beacon',
#  'beads',
#  'beagle',
#  'beak',
#  'beam',
#  'beams',
#  'beans',
#  'bear',
#  'bearing',
#  'bears',
#  'beasts',
#  'beautiful',
#  'beautifully',
#  'beauty',
#  'beavers',
#  'bed',
#  'bedrock',
#  'beds',
#  'bee',
#  'beech',
#  'beef',
#  'beemster',
#  'beer',
#  'bees',
#  'beetle',
#  'beetles',
#  'befits',
#  'beg',
#  'began',
#  'beggars',
#  'begging',
#  'begin',
#  'beginning',
#  'begins',
#  'begun',
#  'behaved',
#  'behaves',
#  'behavior',
#  'behavioral',
#  'behaviorally',
#  'behaviors',
#  'behinds',
#  'beijing',
#  'beings',
#  'belfer',
#  'belief',
#  'beliefs',
#  'believe',
#  'believed',
#  'believes',
#  'believing',
#  'bellied',
#  'bellows',
#  'belong',
#  'belonged',
#  'belonging',
#  'belt',
#  'belts',
#  'bemoaned',
#  'bend',
#  'bending',
#  'beneath',
#  'beneficial',
#  'benefit',
#  'benefited',
#  'benefits',
#  'benefitted',
#  'benoit',
#  'benshi',
#  'bent',
#  'bentley',
#  'bering',
#  'beringia',
#  'beringian',
#  'berlin',
#  'bessemer',
#  'best',
#  'bet',
#  'betokens',
#  'betrays',
#  'better',
#  'betularia',
#  'beveled',
#  'beverages',
#  'bible',
#  'biblical',
#  'bicycle',
#  'big',
#  'bigger',
#  'biggest',
#  'billed',
#  'billion',
#  'billions',
#  'bills',
#  'bind',
#  'binding',
#  'biochemist',
#  'biodiversity',
#  'biogenesis',
#  'biogeographers',
#  'biographer',
#  'biological',
#  'biologist',
#  'biologists',
#  'biology',
#  'biomass',
#  'biome',
#  'biotic',
#  'biotin',
#  'bipedal',
#  'birch',
#  'birches',
#  'bird',
#  'birdlike',
#  'birds',
#  'birmingham',
#  'birth',
#  'birthday',
#  'birthplace',
#  'births',
#  'bison',
#  'biston',
#  ...]

# %%
weight_sum = vectorizer.idf_.sum()
p = list([w / weight_sum for w in vectorizer.idf_])

# %%
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package wordnet to /Users/parsa/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
from googletrans import Translator

# %%
translator = Translator()

# %%
word = np.random.choice(vectorizer.get_feature_names(), 1, p=p)[0]
print(word)
print(translator.translate(word, dest='fa').text)
synonyms = []
for syn in wordnet.synsets(word):
    for lm in syn.lemmas():
        synonyms.append(lm.name())
print(set(synonyms))

antonyms = []
for syn in wordnet.synsets(word):
    for lm in syn.lemmas():
        if lm.antonyms():
            antonyms.append(lm.antonyms()[0].name())
print(set(antonyms))
# Out:
# colder
# سردتر
# {'stale', 'cold-blooded', 'cold', 'inhuman', 'frigid', 'insensate', 'dusty', 'moth-eaten'}
# {'hot'}
